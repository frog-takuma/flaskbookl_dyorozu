# %%
import whisper

# %%
model = whisper.load_model("base")
# result = model.transcribe("準備したファイル名を指定") # 今回の記事ではtest.m4aを用います。

print("type", type("/home/frog-takuma/workspace/web/flaskbook-part1/test_taskkoma.mp3"))
result = model.transcribe("/home/dyorozu/workspase/flaskbook-part2/test_taskkoma.mp3")
print(result["text"])
# Out:
# type <class 'str'>
# ...
